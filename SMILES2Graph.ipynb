# %%
import os.path as osp

import torch

from torch_geometric.nn import SchNet, MessagePassing
from torch_geometric.data import DataLoader
from torch_geometric.datasets import QM9, Planetoid
import os
from pysmiles import read_smiles
from PIL import Image

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')
from tqdm import tqdm

from torch import nn
from torchvision import models
from torch.utils.data import Dataset, DataLoader

# %%
# !python -c "import torch; print(torch.__version__)"
# Out:
# 1.7.1+cu110

# %%
# !python -c "import torch; print(torch.version.cuda)"
# Out:
# 11.0

# %%
train = pd.read_csv(os.path.join('..','data','train.csv'))
dev = pd.read_csv(os.path.join('..','data','dev.csv'))
train = pd.concat([train, dev])
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30345 entries, 0 to 70
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   uid            30345 non-null  object
#  1   SMILES         30345 non-null  object
#  2   S1_energy(eV)  30345 non-null  float64
#  3   T1_energy(eV)  30345 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 1.2+ MB

# %%
train['target'] = train['S1_energy(eV)'] - train['T1_energy(eV)']

# %%
train
# Out:
#         uid                                             SMILES  S1_energy(eV)  \
# 0   train_0   CCC1CCCCN1C(=O)C(C)OC(=O)c1c(C)oc(-n2cccc2)c1C#N         4.6747
# 1   train_1  COc1ccc(Oc2ccc(N3C(=S)NC(c4ccccn4)C3c3cc(C)n(-...         3.6617
# 2   train_2   CC(=O)Nc1ccc(C(=O)[C@H](C)Sc2nnc(C3CCCCC3)o2)cc1         3.6420
# 3   train_3                          OC(CNC1CC1)CN1CCc2sccc2C1         4.8901
# 4   train_4                     CCNC(CCCC(F)(F)F)C1(OCC)CCOCC1         6.4967
# ..      ...                                                ...            ...
# 66   dev_66  N#Cc1cc(-c2ccc(N3c4ccccc4Oc4ccccc43)cc2)c(-c2c...         2.1939
# 67   dev_67  CC1(C)c2ccccc2N(c2ccc(-c3nc4ccc(N5c6ccccc6C(C)...         2.3537
# 68   dev_68  Cc1cc(-n2c3ccc(C(C)(C)C)cc3c3cc(C(C)(C)C)ccc32...         2.1364
# 69   dev_69  Cc1cc(-n2c3ccccc3c3ccccc32)cc(C)c1B1c2ccccc2B(...         2.2650
# 70   dev_70  CC(C)(C)c1ccc2c(c1)c1cc(C(C)(C)C)ccc1n2-c1c(Cl...         2.5477
#
#     T1_energy(eV)  target
# 0          3.3809  1.2938
# 1          3.4585  0.2032
# 2          3.1787  0.4633
# 3          3.7847  1.1054
# 4          6.2724  0.2243
# ..            ...     ...
# 66         2.1846  0.0093
# 67         2.3371  0.0166
# 68         2.1260  0.0104
# 69         2.2511  0.0139
# 70         2.4184  0.1293
#
# [30345 rows x 5 columns]

# %%
mol_list = [Chem.MolFromSmiles(smi) for smi in train['SMILES']]

# %%
y_list = [y for y in train['target']]
len(y_list)
# Out:
# 30345

# %%
len(mol_list)
# Out:
# 30345

# %%
for mol, y in zip(mol_list, y_list):
    print(y)
    break
# Out:
# 1.2937999999999996

# %%
def get_atom_features(mol):
    atomic_number = []
    num_hs = []
    
    for atom in mol.GetAtoms():
        atomic_number.append(atom.GetAtomicNum())
        num_hs.append(atom.GetTotalNumHs(includeNeighbors=True))
        
    return torch.tensor([atomic_number, num_hs]).t()

def get_edge_index(mol):
    row, col = [], []
    
    for bond in mol.GetBonds():
        start, end = bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()
        row += [start, end]
        col += [end, start]
        
    return torch.tensor([row, col], dtype=torch.long)

from torch_geometric.data.dataloader import DataLoader
import torch_geometric.data


def prepare_dataloader(mol_list, y_list):
    data_list = []

    for mol, target in zip(mol_list, y_list):

        x = get_atom_features(mol)
        edge_index = get_edge_index(mol)
        y = target
        data = torch_geometric.data.data.Data(x=x, y=y, edge_index=edge_index)
        data_list.append(data)

    return DataLoader(data_list, batch_size=32, shuffle=True), data_list

# %%
xx = get_atom_features(mol_list[0])
xx
# Out:
# tensor([[6, 3],
#         [6, 2],
#         [6, 1],
#         [6, 2],
#         [6, 2],
#         [6, 2],
#         [6, 2],
#         [7, 0],
#         [6, 0],
#         [8, 0],
#         [6, 1],
#         [6, 3],
#         [8, 0],
#         [6, 0],
#         [8, 0],
#         [6, 0],
#         [6, 0],
#         [6, 3],
#         [8, 0],
#         [6, 0],
#         [7, 0],
#         [6, 1],
#         [6, 1],
#         [6, 1],
#         [6, 1],
#         [6, 0],
#         [6, 0],
#         [7, 0]])

# %%
dloader, dlist = prepare_dataloader(mol_list, y_list)

# %%
dlist
# Out:
# [Data(edge_index=[2, 60], x=[28, 2], y=1.2937999999999996),
#  Data(edge_index=[2, 94], x=[42, 2], y=0.20320000000000027),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.4632999999999998),
#  Data(edge_index=[2, 38], x=[17, 2], y=1.1054000000000004),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.2242999999999995),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.4264000000000001),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.0014000000000003),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.0229000000000004),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.4744999999999999),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.2083000000000004),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.4551000000000003),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.5714999999999999),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.2536999999999998),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.4117999999999995),
#  Data(edge_index=[2, 54], x=[26, 2], y=1.5152999999999999),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.8511999999999995),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6159999999999997),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.7653999999999996),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.5270000000000001),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.3562000000000003),
#  Data(edge_index=[2, 50], x=[24, 2], y=1.0503999999999998),
#  Data(edge_index=[2, 66], x=[29, 2], y=0.4269000000000003),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.9662999999999995),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.41359999999999975),
#  Data(edge_index=[2, 28], x=[15, 2], y=0.47660000000000036),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.3405),
#  Data(edge_index=[2, 68], x=[30, 2], y=0.6490999999999998),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.7543000000000002),
#  Data(edge_index=[2, 44], x=[19, 2], y=0.11840000000000028),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.1149),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.47880000000000056),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.4441000000000006),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.0050000000000003),
#  Data(edge_index=[2, 86], x=[41, 2], y=0.8731999999999998),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.1618),
#  Data(edge_index=[2, 54], x=[26, 2], y=1.1749),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.8486000000000002),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.6095999999999999),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.9183999999999997),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.1532999999999998),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.6223999999999998),
#  Data(edge_index=[2, 24], x=[12, 2], y=0.5724),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.30799999999999983),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.0545),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.3196999999999997),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9306999999999999),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8954999999999997),
#  Data(edge_index=[2, 38], x=[17, 2], y=0.9017000000000008),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.8806999999999996),
#  Data(edge_index=[2, 68], x=[31, 2], y=0.4302999999999999),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.033600000000000296),
#  Data(edge_index=[2, 108], x=[49, 2], y=1.9945000000000004),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.9929999999999999),
#  Data(edge_index=[2, 66], x=[30, 2], y=1.0385999999999997),
#  Data(edge_index=[2, 92], x=[41, 2], y=0.9277000000000002),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.5882999999999994),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.4761999999999995),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.06459999999999955),
#  Data(edge_index=[2, 72], x=[33, 2], y=0.6948999999999996),
#  Data(edge_index=[2, 38], x=[19, 2], y=1.0405999999999995),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.8302),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.8016999999999999),
#  Data(edge_index=[2, 42], x=[19, 2], y=1.0972),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.4878),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.0689000000000002),
#  Data(edge_index=[2, 24], x=[12, 2], y=0.22090000000000032),
#  Data(edge_index=[2, 26], x=[14, 2], y=1.9874999999999998),
#  Data(edge_index=[2, 50], x=[25, 2], y=1.5729000000000002),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.1546000000000003),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.5308000000000006),
#  Data(edge_index=[2, 44], x=[22, 2], y=0.5396000000000001),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.0401000000000002),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.6246),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.024),
#  Data(edge_index=[2, 72], x=[33, 2], y=0.19720000000000004),
#  Data(edge_index=[2, 46], x=[23, 2], y=1.1498),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.7848999999999995),
#  Data(edge_index=[2, 34], x=[17, 2], y=1.2401000000000004),
#  Data(edge_index=[2, 90], x=[43, 2], y=0.5682),
#  Data(edge_index=[2, 80], x=[36, 2], y=0.4777),
#  Data(edge_index=[2, 62], x=[28, 2], y=1.0927000000000002),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.6978999999999997),
#  Data(edge_index=[2, 46], x=[20, 2], y=0.4668000000000001),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.9966999999999997),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.8636000000000004),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.9773999999999994),
#  Data(edge_index=[2, 22], x=[11, 2], y=0.7384999999999993),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.7443999999999997),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.8039999999999998),
#  Data(edge_index=[2, 60], x=[29, 2], y=0.7326000000000001),
#  Data(edge_index=[2, 56], x=[27, 2], y=0.40359999999999996),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.6273000000000004),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.4946999999999999),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.6391),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.7710999999999997),
#  Data(edge_index=[2, 44], x=[22, 2], y=0.9743000000000004),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.6364000000000001),
#  Data(edge_index=[2, 70], x=[32, 2], y=1.0661),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.7213999999999996),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.8195999999999999),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.1651999999999996),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.5659999999999998),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.4406000000000003),
#  Data(edge_index=[2, 38], x=[20, 2], y=0.7051000000000007),
#  Data(edge_index=[2, 56], x=[25, 2], y=1.4562),
#  Data(edge_index=[2, 58], x=[26, 2], y=1.3606999999999996),
#  Data(edge_index=[2, 42], x=[19, 2], y=1.1284999999999998),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.5708000000000002),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.8095000000000003),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.388),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.1486999999999998),
#  Data(edge_index=[2, 40], x=[20, 2], y=1.0392000000000001),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.9363000000000001),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.3593000000000002),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.1347999999999994),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.5324999999999998),
#  Data(edge_index=[2, 50], x=[24, 2], y=1.1326999999999998),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.8980999999999999),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.1781999999999995),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.6531999999999996),
#  Data(edge_index=[2, 58], x=[26, 2], y=1.0804999999999998),
#  Data(edge_index=[2, 36], x=[16, 2], y=0.7666999999999997),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.7229999999999999),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9057999999999993),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.1626000000000003),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.2539000000000007),
#  Data(edge_index=[2, 54], x=[24, 2], y=0.8055000000000003),
#  Data(edge_index=[2, 52], x=[25, 2], y=1.0700000000000012),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.6263000000000001),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.9972999999999996),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.9947999999999997),
#  Data(edge_index=[2, 68], x=[31, 2], y=0.6924000000000001),
#  Data(edge_index=[2, 64], x=[29, 2], y=0.8946000000000001),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.4123),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.8714),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.5362),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.9197000000000006),
#  Data(edge_index=[2, 88], x=[39, 2], y=0.6012),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.7109000000000001),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.8282000000000003),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.4609000000000001),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.5128000000000004),
#  Data(edge_index=[2, 74], x=[33, 2], y=0.9868999999999999),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.46609999999999996),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.3727999999999998),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.9917000000000007),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.1230000000000002),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.1867999999999999),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.5554000000000006),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.35719999999999974),
#  Data(edge_index=[2, 76], x=[34, 2], y=1.0865999999999998),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.5286999999999997),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.4456000000000002),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.0293999999999999),
#  Data(edge_index=[2, 28], x=[15, 2], y=0.11159999999999926),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.8667000000000002),
#  Data(edge_index=[2, 74], x=[33, 2], y=0.6385000000000005),
#  Data(edge_index=[2, 88], x=[41, 2], y=0.7202000000000002),
#  Data(edge_index=[2, 64], x=[29, 2], y=0.9842),
#  Data(edge_index=[2, 108], x=[49, 2], y=0.8201),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.2564000000000002),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.9053),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.5779000000000001),
#  Data(edge_index=[2, 96], x=[41, 2], y=0.8260000000000001),
#  Data(edge_index=[2, 56], x=[27, 2], y=0.7049999999999996),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.3144999999999998),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.8813000000000004),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.9867999999999997),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.9672999999999998),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.1082),
#  Data(edge_index=[2, 74], x=[36, 2], y=1.0888),
#  Data(edge_index=[2, 66], x=[30, 2], y=0.5292000000000003),
#  Data(edge_index=[2, 72], x=[33, 2], y=1.0676),
#  Data(edge_index=[2, 72], x=[33, 2], y=0.9850999999999996),
#  Data(edge_index=[2, 64], x=[29, 2], y=1.1347999999999994),
#  Data(edge_index=[2, 26], x=[12, 2], y=0.5932999999999997),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.5724999999999998),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.6616),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.16419999999999924),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.7728999999999995),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.2477000000000005),
#  Data(edge_index=[2, 74], x=[35, 2], y=0.8744999999999998),
#  Data(edge_index=[2, 34], x=[16, 2], y=1.4123999999999999),
#  Data(edge_index=[2, 68], x=[31, 2], y=1.1637999999999997),
#  Data(edge_index=[2, 54], x=[24, 2], y=1.4279000000000002),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.3783000000000003),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.9598),
#  Data(edge_index=[2, 30], x=[15, 2], y=2.0356000000000005),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.4629000000000003),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.5728),
#  Data(edge_index=[2, 78], x=[35, 2], y=0.5285000000000002),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.5290999999999997),
#  Data(edge_index=[2, 70], x=[32, 2], y=0.8447),
#  Data(edge_index=[2, 62], x=[28, 2], y=1.3070999999999997),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.4662000000000002),
#  Data(edge_index=[2, 104], x=[47, 2], y=1.3683000000000005),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.14719999999999978),
#  Data(edge_index=[2, 36], x=[18, 2], y=0.8876),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.7043000000000004),
#  Data(edge_index=[2, 96], x=[43, 2], y=0.5855999999999995),
#  Data(edge_index=[2, 50], x=[24, 2], y=1.1218999999999997),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.1711999999999998),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.5873999999999997),
#  Data(edge_index=[2, 36], x=[19, 2], y=0.46639999999999926),
#  Data(edge_index=[2, 42], x=[21, 2], y=1.2856),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.3898999999999999),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5301999999999998),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.9470000000000001),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5639000000000003),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.9864999999999999),
#  Data(edge_index=[2, 64], x=[29, 2], y=0.8458000000000006),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.9499),
#  Data(edge_index=[2, 58], x=[28, 2], y=0.45430000000000037),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.5835000000000004),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.49680000000000035),
#  Data(edge_index=[2, 86], x=[40, 2], y=1.1962000000000002),
#  Data(edge_index=[2, 68], x=[32, 2], y=1.0204999999999997),
#  Data(edge_index=[2, 72], x=[32, 2], y=1.1695000000000002),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.1960000000000002),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.6465000000000005),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.1696000000000009),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.1743999999999994),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.9923000000000002),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.0530999999999997),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.0630000000000002),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.7104000000000004),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6928999999999998),
#  Data(edge_index=[2, 62], x=[27, 2], y=0.9788999999999999),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.9140999999999999),
#  Data(edge_index=[2, 82], x=[38, 2], y=0.5105000000000004),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5221999999999984),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6598000000000006),
#  Data(edge_index=[2, 110], x=[48, 2], y=0.14679999999999982),
#  Data(edge_index=[2, 24], x=[12, 2], y=0.4673999999999996),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.2154000000000003),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.5849000000000002),
#  Data(edge_index=[2, 72], x=[32, 2], y=0.34739999999999993),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.3218000000000001),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.8942999999999999),
#  Data(edge_index=[2, 34], x=[15, 2], y=1.6865),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9086000000000003),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.8452999999999999),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.0774),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.6914000000000002),
#  Data(edge_index=[2, 30], x=[15, 2], y=1.1391999999999998),
#  Data(edge_index=[2, 82], x=[37, 2], y=0.8856999999999999),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.43620000000000037),
#  Data(edge_index=[2, 66], x=[30, 2], y=1.1543),
#  Data(edge_index=[2, 30], x=[14, 2], y=1.0943999999999998),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.30400000000000027),
#  Data(edge_index=[2, 68], x=[31, 2], y=0.8720000000000003),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.6948000000000003),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.8767999999999994),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.3195000000000001),
#  Data(edge_index=[2, 64], x=[29, 2], y=1.0108000000000001),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.3657999999999997),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.1223),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.2330999999999999),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.06529999999999969),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.5638000000000005),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.1170999999999998),
#  Data(edge_index=[2, 78], x=[37, 2], y=0.29170000000000007),
#  Data(edge_index=[2, 50], x=[24, 2], y=1.0920000000000005),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.9898999999999996),
#  Data(edge_index=[2, 50], x=[23, 2], y=1.5864999999999996),
#  Data(edge_index=[2, 76], x=[34, 2], y=1.0825),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.7311000000000001),
#  Data(edge_index=[2, 60], x=[27, 2], y=1.1999),
#  Data(edge_index=[2, 78], x=[36, 2], y=0.6606999999999998),
#  Data(edge_index=[2, 38], x=[17, 2], y=0.6475999999999997),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.0177),
#  Data(edge_index=[2, 26], x=[12, 2], y=0.6779000000000002),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.3062000000000005),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.4189000000000003),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.1896000000000004),
#  Data(edge_index=[2, 58], x=[28, 2], y=0.8774),
#  Data(edge_index=[2, 82], x=[38, 2], y=0.9904999999999999),
#  Data(edge_index=[2, 34], x=[17, 2], y=1.0673999999999992),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.26529999999999987),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.8088999999999995),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.7082999999999999),
#  Data(edge_index=[2, 50], x=[24, 2], y=1.1138999999999997),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.8077000000000001),
#  Data(edge_index=[2, 76], x=[35, 2], y=0.9045999999999998),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.8420999999999998),
#  Data(edge_index=[2, 64], x=[29, 2], y=0.7564999999999995),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.8926000000000003),
#  Data(edge_index=[2, 52], x=[23, 2], y=0.5732999999999997),
#  Data(edge_index=[2, 94], x=[44, 2], y=0.9331),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.3501000000000003),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5112999999999999),
#  Data(edge_index=[2, 20], x=[10, 2], y=0.5686),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.013900000000000023),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.6523999999999996),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.1360000000000001),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.5448999999999993),
#  Data(edge_index=[2, 42], x=[19, 2], y=1.0193000000000003),
#  Data(edge_index=[2, 34], x=[16, 2], y=1.415),
#  Data(edge_index=[2, 30], x=[14, 2], y=1.0991999999999997),
#  Data(edge_index=[2, 24], x=[12, 2], y=0.35950000000000015),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.0215999999999998),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.6036000000000001),
#  Data(edge_index=[2, 52], x=[25, 2], y=1.0815999999999995),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.6566999999999998),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.5007999999999999),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.0854999999999997),
#  Data(edge_index=[2, 50], x=[23, 2], y=1.0652),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.5005000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0693000000000001),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.9318),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.45120000000000005),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.13129999999999997),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.8541999999999996),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.3689),
#  Data(edge_index=[2, 72], x=[34, 2], y=0.7290999999999999),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6658000000000004),
#  Data(edge_index=[2, 68], x=[31, 2], y=1.1990999999999996),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.0849000000000002),
#  Data(edge_index=[2, 56], x=[27, 2], y=0.9095000000000004),
#  Data(edge_index=[2, 36], x=[18, 2], y=0.41389999999999993),
#  Data(edge_index=[2, 78], x=[35, 2], y=0.5102000000000002),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.5123999999999995),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.0998999999999999),
#  Data(edge_index=[2, 24], x=[13, 2], y=0.5714999999999995),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.1078999999999999),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.4668000000000001),
#  Data(edge_index=[2, 64], x=[30, 2], y=1.7144000000000004),
#  Data(edge_index=[2, 52], x=[25, 2], y=1.0263),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.37909999999999977),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5621),
#  Data(edge_index=[2, 76], x=[33, 2], y=1.0646999999999998),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.4057999999999997),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.7894000000000001),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.3535000000000004),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.1653000000000002),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.8596000000000004),
#  Data(edge_index=[2, 30], x=[15, 2], y=1.113),
#  Data(edge_index=[2, 66], x=[30, 2], y=0.47970000000000024),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.5994999999999999),
#  Data(edge_index=[2, 58], x=[26, 2], y=1.0629),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.2021000000000002),
#  Data(edge_index=[2, 82], x=[37, 2], y=0.7837999999999998),
#  Data(edge_index=[2, 60], x=[26, 2], y=0.9570000000000003),
#  Data(edge_index=[2, 42], x=[19, 2], y=1.5463000000000005),
#  Data(edge_index=[2, 40], x=[18, 2], y=1.1650000000000005),
#  Data(edge_index=[2, 12], x=[7, 2], y=1.2957999999999998),
#  Data(edge_index=[2, 44], x=[22, 2], y=0.8868),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.6855999999999995),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.43250000000000055),
#  Data(edge_index=[2, 56], x=[27, 2], y=0.935),
#  Data(edge_index=[2, 82], x=[38, 2], y=0.9367000000000005),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.33169999999999966),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6780000000000004),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.23399999999999999),
#  Data(edge_index=[2, 28], x=[15, 2], y=0.1070000000000002),
#  Data(edge_index=[2, 64], x=[29, 2], y=1.2035),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.4319000000000002),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.4857),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.7873999999999999),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.6082),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.7408000000000001),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.7481),
#  Data(edge_index=[2, 68], x=[31, 2], y=0.2049000000000003),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.4011999999999998),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0540000000000003),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.0482000000000005),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.5811999999999999),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.5640999999999998),
#  Data(edge_index=[2, 66], x=[30, 2], y=0.9587000000000003),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.3075999999999999),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.069),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9750999999999999),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.4677000000000002),
#  Data(edge_index=[2, 76], x=[36, 2], y=0.2211000000000003),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.0270000000000001),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.4853999999999994),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9656999999999996),
#  Data(edge_index=[2, 78], x=[35, 2], y=1.1185),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.0),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.6579000000000002),
#  Data(edge_index=[2, 78], x=[40, 2], y=2.480200000000001),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.5933000000000002),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.9590000000000001),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.2270000000000003),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.0738000000000003),
#  Data(edge_index=[2, 106], x=[49, 2], y=1.0433999999999997),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.2416999999999998),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.0433),
#  Data(edge_index=[2, 58], x=[27, 2], y=1.0349999999999997),
#  Data(edge_index=[2, 30], x=[14, 2], y=0.9386000000000005),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.1960000000000002),
#  Data(edge_index=[2, 42], x=[19, 2], y=1.408),
#  Data(edge_index=[2, 68], x=[31, 2], y=1.3290000000000002),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.5831000000000004),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.6310999999999996),
#  Data(edge_index=[2, 70], x=[32, 2], y=1.0760999999999998),
#  Data(edge_index=[2, 22], x=[10, 2], y=0.45760000000000023),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.6001000000000012),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.0383000000000004),
#  Data(edge_index=[2, 56], x=[27, 2], y=1.1174),
#  Data(edge_index=[2, 94], x=[44, 2], y=0.18900000000000006),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.0774),
#  Data(edge_index=[2, 58], x=[27, 2], y=1.1907999999999999),
#  Data(edge_index=[2, 56], x=[25, 2], y=0.4520999999999997),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.009799999999999809),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.9562999999999997),
#  Data(edge_index=[2, 44], x=[22, 2], y=1.1694000000000004),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.5196999999999998),
#  Data(edge_index=[2, 56], x=[25, 2], y=1.1362),
#  Data(edge_index=[2, 76], x=[34, 2], y=0.7592000000000003),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.5758000000000001),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.3281),
#  Data(edge_index=[2, 22], x=[11, 2], y=0.2881),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.9546999999999999),
#  Data(edge_index=[2, 98], x=[44, 2], y=1.0032),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0915999999999997),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.09010000000000007),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9807000000000001),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.7748000000000004),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.09489999999999998),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.5918000000000001),
#  Data(edge_index=[2, 52], x=[23, 2], y=0.9210000000000003),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.7467999999999995),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.9874999999999998),
#  Data(edge_index=[2, 54], x=[26, 2], y=0.9748999999999994),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.35599999999999987),
#  Data(edge_index=[2, 66], x=[29, 2], y=1.0788000000000002),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.3512),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.0097),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.1951),
#  Data(edge_index=[2, 80], x=[36, 2], y=1.4253),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.9651999999999998),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.9918999999999998),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9971999999999999),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.7786000000000004),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.0862999999999996),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.6545999999999998),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.3739000000000008),
#  Data(edge_index=[2, 86], x=[38, 2], y=0.9539),
#  Data(edge_index=[2, 60], x=[26, 2], y=1.3113000000000001),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0857999999999999),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.8725),
#  Data(edge_index=[2, 30], x=[14, 2], y=1.4081000000000001),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.4663000000000004),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.48539999999999983),
#  Data(edge_index=[2, 80], x=[36, 2], y=0.8605999999999998),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.1140999999999996),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.5066000000000006),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.15230000000000032),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.2727),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.0761000000000003),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.4876999999999998),
#  Data(edge_index=[2, 58], x=[27, 2], y=1.4800000000000004),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.2988000000000017),
#  Data(edge_index=[2, 70], x=[32, 2], y=0.7576000000000005),
#  Data(edge_index=[2, 48], x=[24, 2], y=1.2763999999999998),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.7686999999999995),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.0651000000000006),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.3413),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.5920000000000001),
#  Data(edge_index=[2, 36], x=[16, 2], y=0.9773999999999998),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.40749999999999975),
#  Data(edge_index=[2, 50], x=[23, 2], y=1.4274),
#  Data(edge_index=[2, 68], x=[30, 2], y=0.8555000000000001),
#  Data(edge_index=[2, 64], x=[28, 2], y=1.0764),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.8885000000000001),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.9636000000000005),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.7408000000000001),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.1047000000000002),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.7786),
#  Data(edge_index=[2, 22], x=[12, 2], y=0.5384000000000002),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.8323),
#  Data(edge_index=[2, 38], x=[17, 2], y=0.4619),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.46340000000000003),
#  Data(edge_index=[2, 68], x=[31, 2], y=1.4074999999999998),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.03399999999999981),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.1595999999999997),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.4874999999999998),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.29630000000000045),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8653),
#  Data(edge_index=[2, 72], x=[32, 2], y=1.2004000000000001),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.9312),
#  Data(edge_index=[2, 84], x=[39, 2], y=1.1810000000000005),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.5760999999999994),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.24219999999999953),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.5110999999999994),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.8887000000000005),
#  Data(edge_index=[2, 24], x=[12, 2], y=0.9762),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.4960999999999993),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.9338000000000006),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.8085000000000004),
#  Data(edge_index=[2, 86], x=[37, 2], y=1.1118999999999999),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.4651999999999994),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.4518),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.5013000000000001),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.1449999999999996),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.0394),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.9557000000000002),
#  Data(edge_index=[2, 34], x=[15, 2], y=0.7877999999999998),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.37440000000000007),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.7612999999999999),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.5453999999999999),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.5158),
#  Data(edge_index=[2, 84], x=[38, 2], y=0.3822000000000001),
#  Data(edge_index=[2, 66], x=[30, 2], y=1.0406),
#  Data(edge_index=[2, 20], x=[10, 2], y=0.5740999999999996),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.7596000000000003),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.25370000000000026),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.6208),
#  Data(edge_index=[2, 56], x=[25, 2], y=0.8298999999999999),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.6007999999999996),
#  Data(edge_index=[2, 76], x=[34, 2], y=1.1172),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.5974000000000004),
#  Data(edge_index=[2, 36], x=[18, 2], y=0.3623000000000003),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.0044),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9611999999999998),
#  Data(edge_index=[2, 50], x=[22, 2], y=0.6501999999999994),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.5286999999999997),
#  Data(edge_index=[2, 74], x=[33, 2], y=1.3607),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.6068999999999996),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.1549),
#  Data(edge_index=[2, 70], x=[32, 2], y=1.2365999999999997),
#  Data(edge_index=[2, 68], x=[31, 2], y=0.5804),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.4815999999999998),
#  Data(edge_index=[2, 34], x=[18, 2], y=0.10460000000000047),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.8274999999999997),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.5608),
#  Data(edge_index=[2, 38], x=[20, 2], y=0.6819999999999995),
#  Data(edge_index=[2, 90], x=[40, 2], y=1.1441),
#  Data(edge_index=[2, 28], x=[13, 2], y=1.5231),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.6894),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.1039999999999996),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.0118999999999998),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.0933000000000002),
#  Data(edge_index=[2, 62], x=[28, 2], y=1.3072000000000004),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.3676999999999997),
#  Data(edge_index=[2, 64], x=[29, 2], y=1.0049000000000001),
#  Data(edge_index=[2, 40], x=[20, 2], y=1.1431),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.8981000000000003),
#  Data(edge_index=[2, 56], x=[25, 2], y=1.1121999999999996),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.5087999999999999),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.5425999999999993),
#  Data(edge_index=[2, 54], x=[26, 2], y=1.2603),
#  Data(edge_index=[2, 76], x=[34, 2], y=0.5666000000000002),
#  Data(edge_index=[2, 76], x=[35, 2], y=1.1227999999999998),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.9438999999999997),
#  Data(edge_index=[2, 76], x=[34, 2], y=1.1209000000000002),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.2629000000000001),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.9349000000000003),
#  Data(edge_index=[2, 76], x=[33, 2], y=0.5444999999999998),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.0625999999999998),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.6980999999999993),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6303000000000001),
#  Data(edge_index=[2, 82], x=[40, 2], y=2.3821000000000003),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.5816000000000003),
#  Data(edge_index=[2, 52], x=[23, 2], y=1.234),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.4788000000000001),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.5909999999999997),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.17020000000000035),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.5636999999999999),
#  Data(edge_index=[2, 36], x=[19, 2], y=0.37239999999999984),
#  Data(edge_index=[2, 66], x=[31, 2], y=0.8184999999999998),
#  Data(edge_index=[2, 70], x=[32, 2], y=0.9457),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.9090999999999996),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.0394999999999999),
#  Data(edge_index=[2, 46], x=[20, 2], y=0.9819),
#  Data(edge_index=[2, 74], x=[32, 2], y=0.5105),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.36770000000000014),
#  Data(edge_index=[2, 60], x=[29, 2], y=1.0963000000000003),
#  Data(edge_index=[2, 76], x=[35, 2], y=0.5562),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.4939),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.9716),
#  Data(edge_index=[2, 86], x=[39, 2], y=0.31289999999999996),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.5221999999999998),
#  Data(edge_index=[2, 18], x=[10, 2], y=0.6804999999999999),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.0366999999999997),
#  Data(edge_index=[2, 26], x=[13, 2], y=1.8481999999999994),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.2806000000000002),
#  Data(edge_index=[2, 58], x=[27, 2], y=1.3194000000000004),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.1154000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.03630000000000022),
#  Data(edge_index=[2, 90], x=[42, 2], y=0.9318999999999997),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0093),
#  Data(edge_index=[2, 34], x=[18, 2], y=0.5040999999999993),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.9111000000000002),
#  Data(edge_index=[2, 22], x=[12, 2], y=0.5095000000000001),
#  Data(edge_index=[2, 76], x=[37, 2], y=1.1549),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.7431000000000001),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.4964999999999993),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.5889000000000002),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.7216999999999998),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.5867),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.9629999999999996),
#  Data(edge_index=[2, 30], x=[16, 2], y=0.8353000000000002),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.4413999999999998),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.5618000000000003),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.5744000000000002),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.5588999999999995),
#  Data(edge_index=[2, 54], x=[24, 2], y=1.1865999999999994),
#  Data(edge_index=[2, 76], x=[36, 2], y=0.9237000000000002),
#  Data(edge_index=[2, 22], x=[11, 2], y=1.5573000000000001),
#  Data(edge_index=[2, 72], x=[32, 2], y=1.2268),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.0714999999999995),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.30580000000000007),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.6276999999999999),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.5777000000000001),
#  Data(edge_index=[2, 68], x=[32, 2], y=1.0273000000000003),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.0057999999999998),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.0392000000000001),
#  Data(edge_index=[2, 68], x=[32, 2], y=0.7593999999999999),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.8146),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.1415000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.3798999999999997),
#  Data(edge_index=[2, 58], x=[26, 2], y=1.5144000000000002),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.40580000000000016),
#  Data(edge_index=[2, 74], x=[35, 2], y=0.39420000000000055),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.5855999999999999),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.1389000000000005),
#  Data(edge_index=[2, 76], x=[34, 2], y=0.9617),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.9316),
#  Data(edge_index=[2, 62], x=[29, 2], y=0.8865000000000003),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.8852000000000002),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.6392999999999995),
#  Data(edge_index=[2, 96], x=[45, 2], y=0.19510000000000005),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.8835999999999999),
#  Data(edge_index=[2, 50], x=[26, 2], y=1.4161000000000001),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.9626000000000001),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.0008),
#  Data(edge_index=[2, 54], x=[26, 2], y=1.1719),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.5737999999999994),
#  Data(edge_index=[2, 30], x=[14, 2], y=1.3563999999999998),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.3927999999999998),
#  Data(edge_index=[2, 76], x=[34, 2], y=0.7088999999999999),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.5465),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.5392000000000001),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.9788000000000001),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.6252999999999997),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.0964999999999998),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.6747000000000001),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.5),
#  Data(edge_index=[2, 56], x=[27, 2], y=1.2541000000000002),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.8912),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.08410000000000117),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.2793000000000001),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.9817),
#  Data(edge_index=[2, 64], x=[31, 2], y=0.1109),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.698),
#  Data(edge_index=[2, 30], x=[14, 2], y=0.9900000000000002),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.1906999999999996),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.8547000000000002),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.6532999999999998),
#  Data(edge_index=[2, 44], x=[22, 2], y=0.6286999999999994),
#  Data(edge_index=[2, 80], x=[36, 2], y=0.6570999999999998),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.0754000000000001),
#  Data(edge_index=[2, 52], x=[25, 2], y=1.1030000000000002),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.5709999999999997),
#  Data(edge_index=[2, 76], x=[37, 2], y=1.0390000000000001),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.8815),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.32360000000000033),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.7365000000000004),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.2003),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.5776999999999997),
#  Data(edge_index=[2, 66], x=[30, 2], y=1.1179000000000006),
#  Data(edge_index=[2, 84], x=[41, 2], y=1.4208999999999996),
#  Data(edge_index=[2, 72], x=[33, 2], y=1.3680000000000003),
#  Data(edge_index=[2, 76], x=[37, 2], y=1.0402999999999998),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.5245999999999995),
#  Data(edge_index=[2, 76], x=[33, 2], y=1.0519000000000003),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.8890999999999996),
#  Data(edge_index=[2, 46], x=[24, 2], y=0.10389999999999944),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.0103999999999997),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.5047000000000006),
#  Data(edge_index=[2, 30], x=[15, 2], y=1.9011000000000005),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.1345999999999998),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.4038000000000004),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.09220000000000006),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8405000000000005),
#  Data(edge_index=[2, 34], x=[17, 2], y=1.1892999999999998),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.7945000000000002),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.0347999999999997),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.9824999999999995),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.5510000000000002),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.0549),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.7057000000000002),
#  Data(edge_index=[2, 36], x=[18, 2], y=0.9976999999999996),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.3037000000000001),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.3528000000000002),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.1123000000000003),
#  Data(edge_index=[2, 88], x=[40, 2], y=0.7538),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.9800999999999997),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.5495999999999999),
#  Data(edge_index=[2, 70], x=[31, 2], y=0.9670000000000001),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.0466999999999995),
#  Data(edge_index=[2, 60], x=[30, 2], y=2.3231),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.9342999999999999),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.5655000000000001),
#  Data(edge_index=[2, 52], x=[23, 2], y=0.5724999999999998),
#  Data(edge_index=[2, 54], x=[26, 2], y=0.19280000000000008),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.2768999999999995),
#  Data(edge_index=[2, 54], x=[25, 2], y=1.0899999999999999),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.9304999999999994),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.6406999999999998),
#  Data(edge_index=[2, 62], x=[29, 2], y=1.5852),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.042100000000000026),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.1068000000000002),
#  Data(edge_index=[2, 76], x=[35, 2], y=0.6738000000000004),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.8919999999999999),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.0064999999999995),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.9091),
#  Data(edge_index=[2, 42], x=[21, 2], y=1.1308999999999996),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.2439),
#  Data(edge_index=[2, 28], x=[14, 2], y=1.6707999999999998),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.6033),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.5072999999999999),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.5294000000000003),
#  Data(edge_index=[2, 74], x=[33, 2], y=0.4578000000000002),
#  Data(edge_index=[2, 46], x=[23, 2], y=1.1162),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.7639),
#  Data(edge_index=[2, 62], x=[30, 2], y=1.0243000000000002),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.0276),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.8298999999999994),
#  Data(edge_index=[2, 62], x=[29, 2], y=1.3846999999999996),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9678999999999998),
#  Data(edge_index=[2, 70], x=[33, 2], y=1.1833000000000005),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.1704000000000003),
#  Data(edge_index=[2, 72], x=[33, 2], y=1.2483999999999997),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.10260000000000025),
#  Data(edge_index=[2, 70], x=[33, 2], y=0.9570000000000003),
#  Data(edge_index=[2, 54], x=[26, 2], y=1.6498),
#  Data(edge_index=[2, 18], x=[9, 2], y=1.4377000000000004),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.734),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.1683),
#  Data(edge_index=[2, 74], x=[35, 2], y=0.8999999999999999),
#  Data(edge_index=[2, 34], x=[16, 2], y=1.2833999999999999),
#  Data(edge_index=[2, 66], x=[30, 2], y=0.5857000000000001),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.9116),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.5049999999999999),
#  Data(edge_index=[2, 38], x=[19, 2], y=1.0114),
#  Data(edge_index=[2, 46], x=[22, 2], y=0.6372),
#  Data(edge_index=[2, 32], x=[17, 2], y=0.5030999999999999),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.2913999999999999),
#  Data(edge_index=[2, 34], x=[17, 2], y=1.0937000000000001),
#  Data(edge_index=[2, 34], x=[15, 2], y=0.10820000000000007),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.681),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.6541000000000001),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.2843),
#  Data(edge_index=[2, 40], x=[20, 2], y=1.1493000000000002),
#  Data(edge_index=[2, 26], x=[13, 2], y=1.8960000000000004),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.9620000000000002),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.9413),
#  Data(edge_index=[2, 82], x=[37, 2], y=0.7601),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.5395999999999996),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.0710999999999995),
#  Data(edge_index=[2, 54], x=[26, 2], y=0.44310000000000027),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.46050000000000013),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.45920000000000005),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.8793000000000006),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.5769999999999995),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.1564),
#  Data(edge_index=[2, 26], x=[12, 2], y=0.9621),
#  Data(edge_index=[2, 62], x=[30, 2], y=0.5859999999999999),
#  Data(edge_index=[2, 64], x=[29, 2], y=0.9355),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.9860000000000007),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.5956999999999995),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.1190000000000002),
#  Data(edge_index=[2, 56], x=[27, 2], y=1.4196),
#  Data(edge_index=[2, 54], x=[26, 2], y=0.9679000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.4879999999999995),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.6928000000000005),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.8117999999999999),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.9119000000000002),
#  Data(edge_index=[2, 40], x=[18, 2], y=1.0232999999999999),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.3098999999999998),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.45370000000000044),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5242),
#  Data(edge_index=[2, 90], x=[42, 2], y=0.7539000000000002),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.9046000000000003),
#  Data(edge_index=[2, 56], x=[25, 2], y=1.1744999999999997),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.27),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.8937999999999997),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.7161),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.15569999999999995),
#  Data(edge_index=[2, 54], x=[24, 2], y=0.8647000000000005),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.8285),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.3719000000000001),
#  Data(edge_index=[2, 38], x=[19, 2], y=1.0269000000000004),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.9408),
#  Data(edge_index=[2, 64], x=[27, 2], y=1.0965000000000003),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.1423999999999999),
#  Data(edge_index=[2, 92], x=[42, 2], y=0.6845999999999997),
#  Data(edge_index=[2, 94], x=[44, 2], y=1.0223999999999998),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.7697000000000003),
#  Data(edge_index=[2, 60], x=[27, 2], y=0.8416000000000001),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.35020000000000007),
#  Data(edge_index=[2, 32], x=[16, 2], y=0.07030000000000047),
#  Data(edge_index=[2, 26], x=[13, 2], y=0.7379999999999995),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.9394),
#  Data(edge_index=[2, 80], x=[36, 2], y=0.4937999999999998),
#  Data(edge_index=[2, 66], x=[29, 2], y=0.6889000000000003),
#  Data(edge_index=[2, 60], x=[28, 2], y=1.1090999999999998),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.6882999999999999),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.6143000000000001),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.9380000000000006),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.3811999999999998),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.5099999999999998),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.5297999999999998),
#  Data(edge_index=[2, 70], x=[32, 2], y=0.8715999999999999),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.1805000000000003),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.7441000000000004),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.45219999999999994),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9914000000000001),
#  Data(edge_index=[2, 54], x=[24, 2], y=0.7759),
#  Data(edge_index=[2, 24], x=[12, 2], y=1.1817000000000002),
#  Data(edge_index=[2, 62], x=[29, 2], y=1.3502000000000005),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.30859999999999976),
#  Data(edge_index=[2, 42], x=[21, 2], y=1.1623),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.7747000000000002),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.7757000000000001),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.0200999999999998),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.5492),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.6999999999999997),
#  Data(edge_index=[2, 48], x=[24, 2], y=0.4868000000000001),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8321999999999998),
#  Data(edge_index=[2, 24], x=[13, 2], y=0.5462999999999996),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.5316999999999998),
#  Data(edge_index=[2, 36], x=[17, 2], y=1.705),
#  Data(edge_index=[2, 44], x=[22, 2], y=0.5718999999999999),
#  Data(edge_index=[2, 10], x=[6, 2], y=2.0153),
#  Data(edge_index=[2, 64], x=[30, 2], y=1.1267),
#  Data(edge_index=[2, 48], x=[22, 2], y=1.4393000000000002),
#  Data(edge_index=[2, 84], x=[39, 2], y=0.8849999999999998),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.9751000000000003),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.6217000000000001),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.2147999999999999),
#  Data(edge_index=[2, 36], x=[18, 2], y=1.2273),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.6608999999999998),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.7064999999999997),
#  Data(edge_index=[2, 64], x=[29, 2], y=0.11629999999999985),
#  Data(edge_index=[2, 48], x=[22, 2], y=0.2982999999999998),
#  Data(edge_index=[2, 68], x=[29, 2], y=1.2111999999999998),
#  Data(edge_index=[2, 50], x=[24, 2], y=1.0029999999999997),
#  Data(edge_index=[2, 54], x=[24, 2], y=1.2755999999999998),
#  Data(edge_index=[2, 54], x=[26, 2], y=1.1575000000000002),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.7396000000000003),
#  Data(edge_index=[2, 26], x=[12, 2], y=1.0745),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.9766999999999997),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8398999999999996),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.7829000000000006),
#  Data(edge_index=[2, 52], x=[26, 2], y=1.0326000000000004),
#  Data(edge_index=[2, 18], x=[10, 2], y=2.1442000000000005),
#  Data(edge_index=[2, 46], x=[20, 2], y=0.9375),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8760999999999997),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.9540000000000002),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.6153000000000004),
#  Data(edge_index=[2, 80], x=[38, 2], y=0.8106),
#  Data(edge_index=[2, 84], x=[39, 2], y=0.9508999999999999),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.8348999999999998),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.9670000000000005),
#  Data(edge_index=[2, 34], x=[16, 2], y=1.1851000000000003),
#  Data(edge_index=[2, 70], x=[31, 2], y=0.19569999999999999),
#  Data(edge_index=[2, 46], x=[21, 2], y=1.1387),
#  Data(edge_index=[2, 48], x=[21, 2], y=1.1873999999999998),
#  Data(edge_index=[2, 22], x=[12, 2], y=2.5068),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9110999999999998),
#  Data(edge_index=[2, 82], x=[39, 2], y=1.1612999999999998),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.9171000000000005),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.1012000000000004),
#  Data(edge_index=[2, 76], x=[35, 2], y=0.4209999999999998),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.9332999999999996),
#  Data(edge_index=[2, 84], x=[36, 2], y=0.41500000000000004),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.7616),
#  Data(edge_index=[2, 36], x=[18, 2], y=0.13430000000000053),
#  Data(edge_index=[2, 42], x=[19, 2], y=0.6295000000000002),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.1040999999999999),
#  Data(edge_index=[2, 22], x=[11, 2], y=0.5647000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.9965000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.6152999999999986),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.8994999999999997),
#  Data(edge_index=[2, 56], x=[25, 2], y=0.9307000000000003),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.2105999999999999),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.5787),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.7044000000000001),
#  Data(edge_index=[2, 44], x=[23, 2], y=0.6476000000000002),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.0869000000000004),
#  Data(edge_index=[2, 52], x=[23, 2], y=0.746),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.5634000000000001),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.1231999999999998),
#  Data(edge_index=[2, 42], x=[19, 2], y=1.2975000000000003),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.8701999999999996),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.8968999999999996),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.0780000000000003),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.2927000000000004),
#  Data(edge_index=[2, 54], x=[24, 2], y=1.0554999999999999),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.7348),
#  Data(edge_index=[2, 50], x=[25, 2], y=1.1161999999999996),
#  Data(edge_index=[2, 40], x=[20, 2], y=1.0407000000000002),
#  Data(edge_index=[2, 76], x=[35, 2], y=0.07120000000000015),
#  Data(edge_index=[2, 34], x=[16, 2], y=0.7365999999999997),
#  Data(edge_index=[2, 26], x=[12, 2], y=0.38780000000000037),
#  Data(edge_index=[2, 118], x=[49, 2], y=0.9409000000000001),
#  Data(edge_index=[2, 62], x=[30, 2], y=1.0218000000000003),
#  Data(edge_index=[2, 24], x=[12, 2], y=1.0334000000000003),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.7698),
#  Data(edge_index=[2, 38], x=[17, 2], y=1.1913999999999998),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.03530000000000033),
#  Data(edge_index=[2, 54], x=[25, 2], y=0.8472999999999997),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.33599999999999985),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.8060999999999998),
#  Data(edge_index=[2, 38], x=[18, 2], y=0.7284000000000006),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.9355000000000002),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.5366),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.31889999999999974),
#  Data(edge_index=[2, 46], x=[20, 2], y=0.9821000000000004),
#  Data(edge_index=[2, 50], x=[23, 2], y=0.41690000000000005),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.5917),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.6513999999999998),
#  Data(edge_index=[2, 56], x=[25, 2], y=1.0169000000000001),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.9318000000000002),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0536000000000003),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.9805000000000006),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.9287000000000001),
#  Data(edge_index=[2, 52], x=[24, 2], y=1.0093000000000005),
#  Data(edge_index=[2, 40], x=[19, 2], y=1.0378000000000003),
#  Data(edge_index=[2, 52], x=[26, 2], y=0.8186000000000004),
#  Data(edge_index=[2, 40], x=[20, 2], y=0.5814999999999997),
#  Data(edge_index=[2, 40], x=[19, 2], y=0.8549000000000002),
#  Data(edge_index=[2, 32], x=[15, 2], y=0.5661999999999998),
#  Data(edge_index=[2, 70], x=[32, 2], y=0.6837),
#  Data(edge_index=[2, 46], x=[21, 2], y=0.6013999999999999),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.1372999999999998),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.6908000000000003),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.2411000000000003),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9616000000000002),
#  Data(edge_index=[2, 58], x=[26, 2], y=1.2129),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.3913000000000002),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.6917999999999997),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.5021999999999998),
#  Data(edge_index=[2, 46], x=[22, 2], y=1.3739000000000003),
#  Data(edge_index=[2, 56], x=[26, 2], y=1.1667),
#  Data(edge_index=[2, 34], x=[17, 2], y=0.39639999999999986),
#  Data(edge_index=[2, 38], x=[18, 2], y=1.0256000000000003),
#  Data(edge_index=[2, 28], x=[14, 2], y=0.9888000000000003),
#  Data(edge_index=[2, 18], x=[9, 2], y=1.7083),
#  Data(edge_index=[2, 44], x=[21, 2], y=1.0918999999999999),
#  Data(edge_index=[2, 36], x=[17, 2], y=0.41159999999999997),
#  Data(edge_index=[2, 56], x=[25, 2], y=0.6810999999999998),
#  Data(edge_index=[2, 44], x=[22, 2], y=0.47109999999999985),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.09230000000000027),
#  Data(edge_index=[2, 58], x=[26, 2], y=1.0821),
#  Data(edge_index=[2, 42], x=[20, 2], y=0.7084999999999999),
#  Data(edge_index=[2, 66], x=[30, 2], y=0.4161999999999999),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.0047999999999999154),
#  Data(edge_index=[2, 42], x=[21, 2], y=0.9178999999999999),
#  Data(edge_index=[2, 74], x=[33, 2], y=0.31510000000000016),
#  Data(edge_index=[2, 42], x=[20, 2], y=1.5032999999999999),
#  Data(edge_index=[2, 42], x=[21, 2], y=1.1374),
#  Data(edge_index=[2, 64], x=[30, 2], y=1.0735999999999999),
#  Data(edge_index=[2, 70], x=[31, 2], y=0.3842000000000003),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.3664999999999998),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.8572000000000002),
#  Data(edge_index=[2, 80], x=[36, 2], y=0.7160000000000002),
#  Data(edge_index=[2, 62], x=[28, 2], y=1.1623999999999999),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.9160000000000004),
#  Data(edge_index=[2, 50], x=[24, 2], y=0.8164000000000002),
#  Data(edge_index=[2, 44], x=[20, 2], y=1.5403000000000002),
#  Data(edge_index=[2, 58], x=[26, 2], y=0.6495000000000002),
#  Data(edge_index=[2, 48], x=[23, 2], y=0.6788000000000003),
#  Data(edge_index=[2, 78], x=[35, 2], y=1.1185),
#  Data(edge_index=[2, 78], x=[35, 2], y=0.6659999999999999),
#  Data(edge_index=[2, 64], x=[30, 2], y=0.9063999999999997),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.9946000000000006),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.8079999999999998),
#  Data(edge_index=[2, 44], x=[21, 2], y=0.9026000000000001),
#  Data(edge_index=[2, 56], x=[26, 2], y=0.9733),
#  Data(edge_index=[2, 42], x=[19, 2], y=2.1294000000000004),
#  Data(edge_index=[2, 102], x=[48, 2], y=0.4323999999999999),
#  Data(edge_index=[2, 38], x=[19, 2], y=1.3689999999999998),
#  Data(edge_index=[2, 80], x=[37, 2], y=0.7321),
#  Data(edge_index=[2, 36], x=[18, 2], y=0.6762000000000006),
#  Data(edge_index=[2, 48], x=[23, 2], y=1.3702),
#  Data(edge_index=[2, 40], x=[18, 2], y=0.4005000000000001),
#  Data(edge_index=[2, 32], x=[15, 2], y=1.6400000000000001),
#  Data(edge_index=[2, 44], x=[20, 2], y=0.5430999999999999),
#  Data(edge_index=[2, 58], x=[27, 2], y=0.34450000000000003),
#  Data(edge_index=[2, 18], x=[9, 2], y=0.4026999999999994),
#  Data(edge_index=[2, 28], x=[14, 2], y=1.0816999999999997),
#  Data(edge_index=[2, 74], x=[34, 2], y=0.43989999999999974),
#  Data(edge_index=[2, 62], x=[28, 2], y=0.33389999999999986),
#  Data(edge_index=[2, 80], x=[36, 2], y=0.6265000000000001),
#  Data(edge_index=[2, 64], x=[29, 2], y=1.1766),
#  Data(edge_index=[2, 24], x=[12, 2], y=0.8987999999999996),
#  Data(edge_index=[2, 46], x=[23, 2], y=0.24160000000000004),
#  Data(edge_index=[2, 32], x=[16, 2], y=1.1485000000000003),
#  Data(edge_index=[2, 58], x=[28, 2], y=0.8110000000000002),
#  Data(edge_index=[2, 52], x=[24, 2], y=0.8397000000000001),
#  Data(edge_index=[2, 30], x=[15, 2], y=0.20570000000000022),
#  Data(edge_index=[2, 52], x=[25, 2], y=0.30779999999999985),
#  Data(edge_index=[2, 38], x=[19, 2], y=0.43459999999999965),
#  Data(edge_index=[2, 60], x=[28, 2], y=0.5697000000000001),
#  Data(edge_index=[2, 66], x=[31, 2], y=0.9149999999999996),
#  ...]

# %%
for i, batch in enumerate(dloader):
    print(batch.x)    
    if i == 20:
        break
print(batch.x)
# Out:
# tensor([[6, 3],
#         [6, 2],
#         [6, 2],
#         ...,
#         [7, 0],
#         [6, 2],
#         [6, 2]])
# tensor([[8, 0],
#         [6, 0],
#         [6, 2],
#         ...,
#         [6, 2],
#         [6, 2],
#         [6, 2]])
# tensor([[ 6,  3],
#         [ 6,  2],
#         [ 6,  2],
#         ...,
#         [ 6,  1],
#         [ 6,  0],
#         [16,  0]])
# tensor([[8, 0],
#         [6, 0],
#         [6, 2],
#         ...,
#         [6, 0],
#         [8, 0],
#         [8, 1]])
# tensor([[6, 3],
#         [6, 1],
#         [6, 2],
#         ...,
#         [8, 0],
#         [6, 1],
#         [6, 1]])
# tensor([[6, 3],
#         [8, 0],
#         [6, 0],
#         ...,
#         [8, 0],
#         [6, 1],
#         [6, 1]])
# tensor([[ 7,  2],
#         [ 7,  1],
#         [ 6,  0],
#         ...,
#         [ 7,  1],
#         [ 6,  0],
#         [16,  0]])
# tensor([[6, 3],
#         [6, 1],
#         [6, 3],
#         ...,
#         [6, 3],
#         [6, 3],
#         [6, 1]])
# tensor([[6, 3],
#         [6, 0],
#         [6, 1],
#         ...,
#         [6, 1],
#         [6, 1],
#         [7, 0]])
# tensor([[8, 0],
#         [6, 0],
#         [6, 1],
#         ...,
#         [6, 2],
#         [6, 2],
#         [6, 2]])
# tensor([[6, 3],
#         [6, 2],
#         [8, 0],
#         ...,
#         [6, 0],
#         [9, 0],
#         [6, 1]])
# tensor([[17,  0],
#         [16,  0],
#         [ 6,  0],
#         ...,
#         [ 6,  0],
#         [ 8,  0],
#         [ 8,  1]])
# tensor([[6, 3],
#         [8, 0],
#         [6, 0],
#         ...,
#         [6, 0],
#         [6, 0],
#         [6, 1]])
# tensor([[6, 3],
#         [6, 2],
#         [6, 1],
#         ...,
#         [6, 0],
#         [7, 1],
#         [7, 2]])
# tensor([[6, 3],
#         [6, 2],
#         [8, 0],
#         ...,
#         [6, 1],
#         [7, 0],
#         [6, 2]])
# tensor([[6, 3],
#         [8, 0],
#         [6, 1],
#         ...,
#         [6, 1],
#         [6, 1],
#         [6, 1]])
# tensor([[8, 1],
#         [6, 1],
#         [6, 0],
#         ...,
#         [6, 1],
#         [6, 1],
#         [6, 0]])
# tensor([[ 6,  3],
#         [ 6,  2],
#         [ 6,  2],
#         ...,
#         [17,  0],
#         [ 6,  0],
#         [ 7,  0]])
# tensor([[7, 2],
#         [6, 2],
#         [6, 1],
#         ...,
#         [6, 2],
#         [8, 0],
#         [6, 1]])
# tensor([[6, 3],
#         [8, 0],
#         [6, 0],
#         ...,
#         [6, 2],
#         [6, 2],
#         [6, 2]])
# tensor([[6, 3],
#         [6, 0],
#         [6, 1],
#         ...,
#         [6, 1],
#         [7, 0],
#         [7, 0]])
# tensor([[6, 3],
#         [6, 0],
#         [6, 1],
#         ...,
#         [6, 1],
#         [7, 0],
#         [7, 0]])

# %%
dlist[0].x
# Out:
# tensor([[6, 3],
#         [6, 2],
#         [6, 1],
#         [6, 2],
#         [6, 2],
#         [6, 2],
#         [6, 2],
#         [7, 0],
#         [6, 0],
#         [8, 0],
#         [6, 1],
#         [6, 3],
#         [8, 0],
#         [6, 0],
#         [8, 0],
#         [6, 0],
#         [6, 0],
#         [6, 3],
#         [8, 0],
#         [6, 0],
#         [7, 0],
#         [6, 1],
#         [6, 1],
#         [6, 1],
#         [6, 1],
#         [6, 0],
#         [6, 0],
#         [7, 0]])

# %%
dlist[0].y
# Out:
# 1.2937999999999996

# %%
len(dlist)
# Out:
# 30345

# %%
dlist[0].edge_index.t()
# Out:
# tensor([[ 0,  1],
#         [ 1,  0],
#         [ 1,  2],
#         [ 2,  1],
#         [ 2,  3],
#         [ 3,  2],
#         [ 3,  4],
#         [ 4,  3],
#         [ 4,  5],
#         [ 5,  4],
#         [ 5,  6],
#         [ 6,  5],
#         [ 6,  7],
#         [ 7,  6],
#         [ 7,  8],
#         [ 8,  7],
#         [ 8,  9],
#         [ 9,  8],
#         [ 8, 10],
#         [10,  8],
#         [10, 11],
#         [11, 10],
#         [10, 12],
#         [12, 10],
#         [12, 13],
#         [13, 12],
#         [13, 14],
#         [14, 13],
#         [13, 15],
#         [15, 13],
#         [15, 16],
#         [16, 15],
#         [16, 17],
#         [17, 16],
#         [16, 18],
#         [18, 16],
#         [18, 19],
#         [19, 18],
#         [19, 20],
#         [20, 19],
#         [20, 21],
#         [21, 20],
#         [21, 22],
#         [22, 21],
#         [22, 23],
#         [23, 22],
#         [23, 24],
#         [24, 23],
#         [19, 25],
#         [25, 19],
#         [25, 26],
#         [26, 25],
#         [26, 27],
#         [27, 26],
#         [ 7,  2],
#         [ 2,  7],
#         [25, 15],
#         [15, 25],
#         [24, 20],
#         [20, 24]])

# %%
import torch
from torch.nn import Linear
import torch.nn.functional as F 
from torch_geometric.nn import GCNConv, TopKPooling, global_mean_pool
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
embedding_size = 64

class GCN(torch.nn.Module):
    def __init__(self):
        # Init parent
        super(GCN, self).__init__()
        torch.manual_seed(42)

        # GCN layers
        self.initial_conv = GCNConv(2, embedding_size)
        self.conv1 = GCNConv(embedding_size, embedding_size)
        self.conv2 = GCNConv(embedding_size, embedding_size)
        self.conv3 = GCNConv(embedding_size, embedding_size)

        # Output layer
        self.out = Linear(embedding_size*2, 1)

    def forward(self, x, edge_index, batch_index):
        # First Conv layer
        hidden = self.initial_conv(x, edge_index)
        hidden = F.tanh(hidden)

        # Other Conv layers
        hidden = self.conv1(hidden, edge_index)
        hidden = F.tanh(hidden)
        hidden = self.conv2(hidden, edge_index)
        hidden = F.tanh(hidden)
        hidden = self.conv3(hidden, edge_index)
        hidden = F.tanh(hidden)
          
        # Global Pooling (stack different aggregations)
        hidden = torch.cat([gmp(hidden, batch_index), 
                            gap(hidden, batch_index)], dim=1)

        # Apply a final (linear) classifier.
        out = self.out(hidden)

        return out, hidden

model = GCN()
print(model)
print("Number of parameters: ", sum(p.numel() for p in model.parameters()))
# Out:
# GCN(
#   (initial_conv): GCNConv(2, 64)
#   (conv1): GCNConv(64, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )
# Number of parameters:  12801

# %%
from torch_geometric.data import DataLoader
import warnings
warnings.filterwarnings("ignore")

# Root mean squared error
loss_fn = torch.nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0007)  

# Use GPU for training
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Wrap data in a data loader
data = dlist
data_size = len(data)
NUM_GRAPHS_PER_BATCH = 64
loader = DataLoader(data[:int(data_size * 0.8)], 
                    batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)
test_loader = DataLoader(data[int(data_size * 0.8):], 
                         batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)


def train(data):
    # Enumerate over the data
    for batch in loader:
        # Use GPU
        batch.to(device)  
        # Reset gradients
        optimizer.zero_grad() 
        # Passing the node features and the connection info
        pred, embedding = model(batch.x.float(), batch.edge_index, batch.batch) 
        # Calculating the loss and gradients
        loss = loss_fn(pred, batch.y)
        loss.backward()  
        # Update using the gradients
        optimizer.step()   
    return loss, embedding

print("Starting training...")
losses = []
for epoch in range(2000):
    loss, h = train(data)
    losses.append(loss)
    if epoch % 10 == 0:
        print(f"Epoch {epoch} | Train Loss {loss}")
# Out:
# Starting training...
# Epoch 0 | Train Loss 0.27015265822410583
# Epoch 10 | Train Loss 0.32737502455711365
# Epoch 20 | Train Loss 0.2162427455186844
# Epoch 30 | Train Loss 0.3440459370613098
# Epoch 40 | Train Loss 0.29982790350914
# Epoch 50 | Train Loss 0.2987600564956665
# Epoch 60 | Train Loss 0.2284633070230484
# Epoch 70 | Train Loss 0.37255802750587463
# Epoch 80 | Train Loss 0.30166998505592346
# Epoch 90 | Train Loss 0.35933470726013184
